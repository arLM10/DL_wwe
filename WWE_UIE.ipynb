# %%
# !git clone https://github.com/chingheng0808/WWE-UIE.git
# %cd WWE-UIE
# Out:
# Cloning into 'WWE-UIE'...
# remote: Enumerating objects: 139, done.
# remote: Counting objects: 100% (139/139), done.
# remote: Compressing objects: 100% (138/138), done.
# remote: Total 139 (delta 67), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (139/139), 12.69 MiB | 15.10 MiB/s, done.
# Resolving deltas: 100% (67/67), done.
# /content/WWE-UIE

# %%
# !pip install -q thop einops huggingface_hub gdown

# %%
# %cd /content/WWE-UIE
# !gdown --fuzzy https://drive.google.com/file/d/1ceeWdqRdiIortVTSH0UNTZamHdMsZ3aA/view -O /content/dataset.zip
# !unzip -q /content/dataset.zip -d /content/
# !mkdir UnderWaterDataset
# !mv UIEB LSUI UFO-120 EUVP EUVP-Dark Challenging-60 U45  UnderWaterDataset/
# Out:
# /content/WWE-UIE
# Downloading...
# From (original): https://drive.google.com/uc?id=1ceeWdqRdiIortVTSH0UNTZamHdMsZ3aA
# From (redirected): https://drive.google.com/uc?id=1ceeWdqRdiIortVTSH0UNTZamHdMsZ3aA&confirm=t&uuid=bc074db6-4d7b-481b-92b8-4b4780ace5b5
# To: /content/dataset.zip
# 100% 2.63G/2.63G [00:40<00:00, 64.4MB/s]
# mv: cannot stat 'UIEB': No such file or directory
# mv: cannot stat 'LSUI': No such file or directory
# mv: cannot stat 'UFO-120': No such file or directory
# mv: cannot stat 'EUVP': No such file or directory
# mv: cannot stat 'EUVP-Dark': No such file or directory
# mv: cannot stat 'Challenging-60': No such file or directory
# mv: cannot stat 'U45': No such file or directory

# %%
# !gdown --fuzzy https://drive.google.com/file/d/1c80kkDbgpLD1MtqVLql1Y1NQVD7IzxiO/view -O /content/WWE-UIE/best_model.pth
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1c80kkDbgpLD1MtqVLql1Y1NQVD7IzxiO
# To: /content/WWE-UIE/best_model.pth
# 100% 3.05M/3.05M [00:00<00:00, 19.0MB/s]

# %%
# %cd /content/WWE-UIE
# Out:
# /content/WWE-UIE

# %%
cd /content/WWE-UIE
# Out:
# /content/WWE-UIE

# %%
# !sed -i 's#/ssddd/chingheng/UnderWaterDataset#/content/WWE-UIE/UnderWaterDataset#g' \
    test.py train.py test_nr.py

# %%
# !python train.py \
    --dataset UIEB \
    --epoch 100 \
    --train_batch_size 24 \
    --model_name WWE_UIEB
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# Traceback (most recent call last):
#   File "/content/WWE-UIE/train.py", line 283, in <module>
#     main()
#   File "/content/WWE-UIE/train.py", line 276, in main
#     trainer.training()
#   File "/content/WWE-UIE/train.py", line 157, in training
#     vgg_loss = self.vggL(pred, label)
#                ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/WWE-UIE/utils/loss_funcs.py", line 32, in forward
#     pred_im_features = self.output_features(pred_im)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/WWE-UIE/utils/loss_funcs.py", line 25, in output_features
#     x = module(x)
#         ^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1790, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/pooling.py", line 224, in forward
#     return F.max_pool2d(
#            ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_jit_internal.py", line 636, in fn
#     return if_false(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/functional.py", line 835, in _max_pool2d
#     return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 192.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 99.81 MiB is free. Including non-PyTorch memory, this process has 14.46 GiB memory in use. Of the allocated memory 14.30 GiB is allocated by PyTorch, and 44.82 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)

# %%
# !python train.py \
    --dataset UIEB \
    --epoch 100 \
    --train_batch_size 4
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# [1/100], avg. loss is 0.19539081820108917, learning rate is 0.002
# [Validation] SSIM: 0.8705, PSNR: 20.5057
# [2/100], avg. loss is 0.17012419769268358, learning rate is 0.001999506609709695
# [Validation] SSIM: 0.8745, PSNR: 20.7318
# [3/100], avg. loss is 0.16089578592375423, learning rate is 0.001998026925755429
# [Validation] SSIM: 0.8796, PSNR: 20.6325
# [4/100], avg. loss is 0.15810751395948816, learning rate is 0.00199556240840662
# [Validation] SSIM: 0.8814, PSNR: 20.9507
# [5/100], avg. loss is 0.15528950287719792, learning rate is 0.001992115489844347
# [Validation] SSIM: 0.8875, PSNR: 21.3522
# [6/100], avg. loss is 0.151815602660514, learning rate is 0.0019876895717610785
# [Validation] SSIM: 0.8893, PSNR: 21.5199
# [7/100], avg. loss is 0.14565916267338763, learning rate is 0.0019822890220036163
# [Validation] SSIM: 0.8909, PSNR: 21.3963
# [8/100], avg. loss is 0.14258866020467845, learning rate is 0.001975919170262554
# [Validation] SSIM: 0.8961, PSNR: 21.8886
# [9/100], avg. loss is 0.14129731117674474, learning rate is 0.0019685863028125186
# [Validation] SSIM: 0.8930, PSNR: 21.9017
# [10/100], avg. loss is 0.13657016156429655, learning rate is 0.001960297656308376
# [Validation] SSIM: 0.8977, PSNR: 22.1379
# [11/100], avg. loss is 114.53298791167273, learning rate is 0.0019510614106435242
# [Validation] SSIM: 0.0118, PSNR: 5.4598
# [12/100], avg. loss is 6852679.563515502, learning rate is 0.0019408866808773302
# [Validation] SSIM: 0.0855, PSNR: 4.9626
# [13/100], avg. loss is 9310.310620940134, learning rate is 0.0019297835082396626
# [Validation] SSIM: 0.0579, PSNR: 4.7995
# [14/100], avg. loss is 3922.5146196343926, learning rate is 0.0019177628502214125
# [Validation] SSIM: 0.0600, PSNR: 4.7625
# [15/100], avg. loss is 2163.4923411165732, learning rate is 0.0019048365697607729
# [Validation] SSIM: 0.0664, PSNR: 4.7841
# [16/100], avg. loss is 1287.5540565747892, learning rate is 0.001891017423535949
# [Validation] SSIM: 0.0748, PSNR: 4.7591
# [17/100], avg. loss is 920.538219323319, learning rate is 0.001876319049375859
# [Validation] SSIM: 0.0585, PSNR: 4.7563
# [18/100], avg. loss is 693.8645739608936, learning rate is 0.0018607559528012432
# [Validation] SSIM: 0.0512, PSNR: 4.7711
# [19/100], avg. loss is 564.8680896544724, learning rate is 0.0018443434927094648
# [Validation] SSIM: 0.0506, PSNR: 4.7589
# [20/100], avg. loss is 468.83942987677756, learning rate is 0.0018270978662171342
# [Validation] SSIM: 0.0545, PSNR: 4.8041
# [21/100], avg. loss is 382.5737398983388, learning rate is 0.0018090360926755098
# [Validation] SSIM: 0.0482, PSNR: 4.8095
# [22/100], avg. loss is 303.09360272696847, learning rate is 0.0017901759968744525
# [Validation] SSIM: 0.0570, PSNR: 4.8479
# [23/100], avg. loss is 235.22709450025238, learning rate is 0.0017705361914515116
# [Validation] SSIM: 0.0588, PSNR: 4.8906
# [24/100], avg. loss is 192.1443665322293, learning rate is 0.0017501360585234964
# [Validation] SSIM: 0.0807, PSNR: 4.8901
# [25/100], avg. loss is 164.3723689304309, learning rate is 0.0017289957305586692
# [Validation] SSIM: 0.0669, PSNR: 4.9335
# [26/100], avg. loss is 145.53261664744173, learning rate is 0.0017071360705084287
# [Validation] SSIM: 0.0767, PSNR: 4.9227
# [27/100], avg. loss is 128.70194175805938, learning rate is 0.0016845786512180957
# [Validation] SSIM: 0.0760, PSNR: 4.9447
# [28/100], avg. loss is 115.73299137929853, learning rate is 0.0016613457341371194
# [Validation] SSIM: 0.0661, PSNR: 4.9811
# [29/100], avg. loss is 104.43346773640494, learning rate is 0.0016374602473497148
# [Validation] SSIM: 0.0660, PSNR: 4.9980
# [30/100], avg. loss is 95.27119379365043, learning rate is 0.0016129457629476113
# [Validation] SSIM: 0.0611, PSNR: 4.9652
# [31/100], avg. loss is 87.38215350033192, learning rate is 0.001587826473767244
# [Validation] SSIM: 0.0499, PSNR: 5.0198
# [32/100], avg. loss is 78.98405422253555, learning rate is 0.0015621271695143454
# [Validation] SSIM: 0.0448, PSNR: 5.0412
# [33/100], avg. loss is 72.75237383467427, learning rate is 0.0015358732122994986
# [Validation] SSIM: 0.0424, PSNR: 5.0157
# [34/100], avg. loss is 66.8326339293062, learning rate is 0.0015090905116087962
# [Validation] SSIM: 0.0474, PSNR: 5.0408
# [35/100], avg. loss is 61.69779149601968, learning rate is 0.001481805498734305
# [Validation] SSIM: 0.0471, PSNR: 5.0701
# [36/100], avg. loss is 56.601212019331, learning rate is 0.0014540451006895727
# [Validation] SSIM: 0.0279, PSNR: 5.1054
# [37/100], avg. loss is 53.035566501403125, learning rate is 0.001425836713635916
# [Validation] SSIM: 0.0416, PSNR: 5.0914
# [38/100], avg. loss is 49.937074136198234, learning rate is 0.001397208175845717
# [Validation] SSIM: 0.0306, PSNR: 5.1230
# [39/100], avg. loss is 45.96817566303724, learning rate is 0.0013681877402294095
# [Validation] SSIM: 0.0201, PSNR: 5.1725
# [40/100], avg. loss is 42.99030669351642, learning rate is 0.0013388040464532669
# [Validation] SSIM: 0.0324, PSNR: 5.1348
# [41/100], avg. loss is 40.50564510902662, learning rate is 0.0013090860926755097
# [Validation] SSIM: 0.0348, PSNR: 5.1272
# [42/100], avg. loss is 38.44298832068282, learning rate is 0.0012790632069286253
# [Validation] SSIM: 0.0279, PSNR: 5.1355
# [43/100], avg. loss is 36.353844203306046, learning rate is 0.0012487650181761379
# [Validation] SSIM: 0.0347, PSNR: 5.1567
# [44/100], avg. loss is 33.44667688648352, learning rate is 0.0012182214270724029
# [Validation] SSIM: 0.0277, PSNR: 5.1940
# [45/100], avg. loss is 31.62821125716306, learning rate is 0.001187462576454266
# [Validation] SSIM: 0.0621, PSNR: 5.0984
# [46/100], avg. loss is 30.16755844501967, learning rate is 0.0011565188215937267
# [Validation] SSIM: 0.0346, PSNR: 5.1675
# [47/100], avg. loss is 28.298876623089395, learning rate is 0.001125420700240948
# [Validation] SSIM: 0.0267, PSNR: 5.2152
# [48/100], avg. loss is 26.412207517731055, learning rate is 0.0010941989024871824
# [Validation] SSIM: 0.0327, PSNR: 5.2034
# [49/100], avg. loss is 25.130672958459748, learning rate is 0.0010628842404773605
# [Validation] SSIM: 0.0245, PSNR: 5.2270
# [50/100], avg. loss is 23.589131837480522, learning rate is 0.0010315076180022204
# The accuracy of the best round is  {'best epoch': 10, 'best PSNR': np.float64(22.137868218528734), 'best SSIM': np.float32(0.89772636)}
# The total training time is: 6287.811436653137
